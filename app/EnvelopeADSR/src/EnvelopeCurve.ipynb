# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# attack
_maxLevel = 4096
_attack = 100
ex_ = []
for i in range(_attack):
    _level = _maxLevel - (math.exp(-1 * i * (3.0 / _attack)) * _maxLevel)
    ex_.append(_level)
print(ex_[-1])
plt.plot(ex_)
plt.grid(True)
plt.show()
# Out:
# 3885.861640880459

# %%
# attack 2
_maxLevel = 4096
_attack = 2345
ex_ = []
for i in range(_attack):
    _level = (math.exp(i * (10.0 / _attack)) / math.exp(10.0))
    ex_.append(_level)
print(ex_[-1])
plt.plot(ex_)
plt.grid(True)
plt.show()
_attack * (10.0 / _attack)
# Out:
# 0.9957446872859278
# 10.0

# %%
# decay
_maxLevel = 4096
_sustain = 2000
_decay = 200
ex_ = []
for i in range(_decay):
    _level = (math.exp(-1 * i * (10.0 / _decay)) * (_maxLevel - _sustain)) + _sustain
    ex_.append(_level)
print(ex_[-1])
plt.plot(ex_)
plt.grid(True)
plt.show()
# Out:
# 2000.1000371207315

# %%
# release
_maxLevel = 4096
_sustain = 2000
_release = 200
ex_ = []
for i in range(_release):
    _level = (math.exp(-1 * i * (5.0 / _release)) * (_sustain))
    ex_.append(_level)
print(ex_[-1])
plt.plot(ex_)
plt.grid(True)
plt.show()
# Out:
# 13.817037878909051
